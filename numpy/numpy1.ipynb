# %%
# array = numpy.array([])

import numpy as np

l1 = np.array([10,20,30,40])
l2 = np.array([40,30,20,10])

print(l1+l2)
# Out:
# [50 50 50 50]

# %%
l1 = np.array([10,20,30,40,5])
l2 = np.array([5])
print(l1*l2)

print(np.shape(l1))
print(np.size(l1))
# Out:
# [ 50 100 150 200  25]
# (5,)
# 5

# %%
# np.shape(l1)         # return how many row and how many column (row,column)

# np.size(le)         # return size of array row*column

# np.ndim(l1)        # ndim means number od dimention  

# l1.dtype       # return which type of data are store 

# le.astype(int)  = convert on array to a different type

# len(l1)            # return length

# %%
arr  = np.array([[10,20,30,40],[50,60,70,80],[90,10,20,30]])
print(arr)

print(np.shape(arr))   # 3,4

print(np.size(arr))   # 12

print(np.ndim(arr))   # 2
# Out:
# [[10 20 30 40]
#  [50 60 70 80]
#  [90 10 20 30]]
# (3, 4)
# 12
# 2

# %%
# # mathematical operation and functions on arrays

# g=  a-b 
# np.subtract(a,b)

# g= a+b
# np.add(a,b)

# a/b
# np.divide(a,b)

# a*b
# np.multiply(a,b)

# np.exp(b)      #exponential

# np.sqrt(b)

# np.pow(a)

# %%
import numpy as np

a = np.array([10,20,30,40,50])
a2 = np.array([10,20,30,40,50])

print(a+a2)

np.add(a,a2)
# Out:
# [ 20  40  60  80 100]
# array([ 20,  40,  60,  80, 100])

# %% [markdown]
# ##![image.png](attachment:aec87c58-0737-4040-931f-4894b086aed7.png)

# %%
a = np.array([10,20,30,40,50])
a2 = np.array([10,20,30,40,50])

print(np.hstack([a,a2]))
# Out:
# [10 20 30 40 50 10 20 30 40 50]

# %%
import numpy as np

a = np.array([10,20],[40,50])
a2 = np.array([50,700],[50,60])

print(np.vstack([a,a2]))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 3
#       1 import numpy as np
# ----> 3 a = np.array([10,20],[40,50])
#       4 a2 = np.array([50,700],[50,60])
#       6 print(np.vstack([a,a2]))
#
# TypeError: Field elements must be 2- or 3-tuples, got '40'
