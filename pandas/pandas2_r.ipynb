# %%
import pandas as pd
import numpy as np

# %%
# open placement data


df = pd.read_csv("C:\\Users\\91937\\OneDrive\\Desktop\\Dataframe\\placement.csv")

df
# Out:
#     cgpa  resume_score  placed
# 0   8.14          6.52       1
# 1   6.17          5.17       0
# 2   8.27          8.86       1
# 3   6.88          7.27       1
# 4   7.52          7.30       1
# ..   ...           ...     ...
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0
#
# [100 rows x 3 columns]

# %%
df.head()   # top 5 values of data
# Out:
#    cgpa  resume_score  placed
# 0  8.14          6.52       1
# 1  6.17          5.17       0
# 2  8.27          8.86       1
# 3  6.88          7.27       1
# 4  7.52          7.30       1

# %%
df.tail()      #bottom  5 values  data
# Out:
#     cgpa  resume_score  placed
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0

# %%
df.describe()        # Statically view of data
# Out:
#            cgpa  resume_score      placed
# count  100.0000    100.000000  100.000000
# mean     6.9422      6.930500    0.500000
# std      1.1192      0.979608    0.502519
# min      5.2700      4.950000    0.000000
# 25%      5.9800      6.190000    0.000000
# 50%      6.6200      7.055000    0.500000
# 75%      8.0450      7.640000    1.000000
# max      9.4000      9.060000    1.000000

# %%
df.info()      # .info() return structure of data and return data type of data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   cgpa          100 non-null    float64
#  1   resume_score  100 non-null    float64
#  2   placed        100 non-null    int64
# dtypes: float64(2), int64(1)
# memory usage: 2.5 KB

# %%
top_left_corner = df.iloc[:4,:3]    # iloc [row_range,column_range]
top_left_corner
# Out:
#    cgpa  resume_score  placed
# 0  8.14          6.52       1
# 1  6.17          5.17       0
# 2  8.27          8.86       1
# 3  6.88          7.27       1

# %%
df.loc[1:5]             #  loc [row_range,column_range] ,include first and last indexing both
# Out:
#    cgpa  resume_score  placed
# 1  6.17          5.17       0
# 2  8.27          8.86       1
# 3  6.88          7.27       1
# 4  7.52          7.30       1
# 5  8.77          6.19       1

# %%
df.loc[1:5   ,['cgpa','placed'] ]
# Out:
#    cgpa  placed
# 1  6.17       0
# 2  8.27       1
# 3  6.88       1
# 4  7.52       1
# 5  8.77       1

# %%
s = df.axes            # How many roow my data and  each row gap 
s
# Out:
# [RangeIndex(start=0, stop=100, step=1),
#  Index(['cgpa', 'resume_score', 'placed'], dtype='object')]

# %%
a = df.dtypes       # define data type in each column 
a
# Out:
# cgpa            float64
# resume_score    float64
# placed            int64
# dtype: object

# %%
b= df.empty           # it return true if there any missing data in dataframe otherwise return false 
b
# Out:
# False

# %%
a = df.isnull().sum()         # for check null values 
a
# Out:
# cgpa            0
# resume_score    0
# placed          0
# dtype: int64

# %%
df.dropna()          # for remove missing data
# Out:
#     cgpa  resume_score  placed
# 0   8.14          6.52       1
# 1   6.17          5.17       0
# 2   8.27          8.86       1
# 3   6.88          7.27       1
# 4   7.52          7.30       1
# ..   ...           ...     ...
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0
#
# [100 rows x 3 columns]

# %%
a = df.ndim                 # number of dimention 
a
# Out:
# 2

# %%
t= df.shape           (row,column)
t
# Out:
# (100, 3)

# %%
s = df.size        # (row * column)
s
# Out:
# 300

# %%
a = df.values           # get a numpy array for df
a
# Out:
# array([[8.14, 6.52, 1.  ],
#        [6.17, 5.17, 0.  ],
#        [8.27, 8.86, 1.  ],
#        [6.88, 7.27, 1.  ],
#        [7.52, 7.3 , 1.  ],
#        [8.77, 6.19, 1.  ],
#        [5.34, 7.09, 0.  ],
#        [6.56, 6.29, 0.  ],
#        [6.32, 6.71, 0.  ],
#        [7.69, 7.12, 1.  ],
#        [6.18, 6.35, 0.  ],
#        [5.44, 6.54, 0.  ],
#        [6.09, 7.01, 0.  ],
#        [8.5 , 5.09, 1.  ],
#        [7.51, 6.25, 1.  ],
#        [8.88, 5.93, 1.  ],
#        [8.04, 7.64, 1.  ],
#        [7.81, 8.71, 1.  ],
#        [5.94, 5.88, 0.  ],
#        [6.75, 8.11, 1.  ],
#        [5.8 , 8.06, 0.  ],
#        [6.53, 7.64, 0.  ],
#        [6.16, 5.77, 0.  ],
#        [6.05, 7.13, 0.  ],
#        [8.22, 6.18, 1.  ],
#        [7.76, 5.68, 1.  ],
#        [6.27, 6.47, 0.  ],
#        [5.51, 6.15, 0.  ],
#        [7.46, 7.67, 1.  ],
#        [6.19, 7.3 , 0.  ],
#        [7.36, 7.15, 1.  ],
#        [5.92, 7.02, 0.  ],
#        [5.87, 7.96, 0.  ],
#        [8.43, 7.73, 1.  ],
# ...

# %%
df2 = df.copy()                 # Copy data 
df2
# Out:
#     cgpa  resume_score  placed
# 0   8.14          6.52       1
# 1   6.17          5.17       0
# 2   8.27          8.86       1
# 3   6.88          7.27       1
# 4   7.52          7.30       1
# ..   ...           ...     ...
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0
#
# [100 rows x 3 columns]

# %%
s = df.sort_values(by = "cgpa")             # Sort data bases of "Cgpa"
s
# Out:
#     cgpa  resume_score  placed
# 79  5.27          7.28       0
# 6   5.34          7.09       0
# 92  5.43          6.18       0
# 11  5.44          6.54       0
# 49  5.46          6.73       0
# ..   ...           ...     ...
# 34  8.87          7.19       1
# 15  8.88          5.93       1
# 37  9.05          8.21       1
# 93  9.31          7.39       1
# 76  9.40          5.50       1
#
# [100 rows x 3 columns]

# %%
# x = df.astype(int)  #type conversion
df['cgpa'] = df['cgpa'].astype(int)
df
# Out:
#     cgpa  resume_score  placed
# 0      8          6.52       1
# 1      6          5.17       0
# 2      8          8.86       1
# 3      6          7.27       1
# 4      7          7.30       1
# ..   ...           ...     ...
# 95     6          6.38       0
# 96     8          7.76       1
# 97     6          7.78       0
# 98     8          5.63       1
# 99     6          6.61       0
#
# [100 rows x 3 columns]

# %%
a = df["Cgpa"] = df["cgpa"].astype(int)          # clumn name is case sensitive

# %%
df
# Out:
#     cgpa  resume_score  placed  Cgpa
# 0      8          6.52       1     8
# 1      6          5.17       0     6
# 2      8          8.86       1     8
# 3      6          7.27       1     6
# 4      7          7.30       1     7
# ..   ...           ...     ...   ...
# 95     6          6.38       0     6
# 96     8          7.76       1     8
# 97     6          7.78       0     6
# 98     8          5.63       1     8
# 99     6          6.61       0     6
#
# [100 rows x 4 columns]

# %%
df.drop(columns = ["Cgpa"])         # Remove column
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[72], line 1
# ----> 1 df.drop(columns = ["Cgpa"])
#
# File D:\anakonda\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
#
# ...

# %%
df
# Out:
#     cgpa  resume_score  placed
# 0      8          6.52       1
# 1      6          5.17       0
# 2      8          8.86       1
# 3      6          7.27       1
# 4      7          7.30       1
# ..   ...           ...     ...
# 95     6          6.38       0
# 96     8          7.76       1
# 97     6          7.78       0
# 98     8          5.63       1
# 99     6          6.61       0
#
# [100 rows x 3 columns]

# %%
p = a             # copy data
df
# Out:
#     cgpa  resume_score  placed
# 0      8             6       1
# 1      6             5       0
# 2      8             8       1
# 3      6             7       1
# 4      7             7       1
# ..   ...           ...     ...
# 95     6             6       0
# 96     8             7       1
# 97     6             7       0
# 98     8             5       1
# 99     6             6       0
#
# [100 rows x 3 columns]

# %%
# p['resume_score']  = p['resume_score'].astype(int)
p
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[66], line 1
# ----> 1 p['resume_score']  = p['resume_score'].astype(int)
#       2 p
#
# File D:\anakonda\Lib\site-packages\pandas\core\series.py:1121, in Series.__getitem__(self, key)
#    1118     return self._values[key]
#    1120 elif key_is_scalar:
# -> 1121     return self._get_value(key)
#    1123 # Convert generator to list before going through hashable part
#    1124 # (We will iterate through the generator there to check for slices)
#    1125 if is_iterator(key):
#
# File D:\anakonda\Lib\site-packages\pandas\core\series.py:1237, in Series._get_value(self, label, takeable)
#    1234     return self._values[label]
#    1236 # Similar to Index.get_value, but we do not fall back to positional
# -> 1237 loc = self.index.get_loc(label)
#    1239 if is_integer(loc):
#    1240     return self._values[loc]
#
# ...

# %%
df
# Out:
#     cgpa  resume_score  placed
# 0      8             6       1
# 1      6             5       0
# 2      8             8       1
# 3      6             7       1
# 4      7             7       1
# ..   ...           ...     ...
# 95     6             6       0
# 96     8             7       1
# 97     6             7       0
# 98     8             5       1
# 99     6             6       0
#
# [100 rows x 3 columns]

# %%
df
# Out:
#     cgpa  resume_score  placed
# 0      8             6       1
# 1      6             5       0
# 2      8             8       1
# 3      6             7       1
# 4      7             7       1
# ..   ...           ...     ...
# 95     6             6       0
# 96     8             7       1
# 97     6             7       0
# 98     8             5       1
# 99     6             6       0
#
# [100 rows x 3 columns]

# %%
# t = df.add(number)              # add number in particulr column

# %%
df['cgpa'] = df['cgpa'].add(4)

# %%
df
# Out:
#     cgpa  resume_score  placed
# 0     12             6       1
# 1     10             5       0
# 2     12             8       1
# 3     10             7       1
# 4     11             7       1
# ..   ...           ...     ...
# 95    10             6       0
# 96    12             7       1
# 97    10             7       0
# 98    12             5       1
# 99    10             6       0
#
# [100 rows x 3 columns]

# %%
df['resume_score'] = df['resume_score'].add(2)

# %%
df
# Out:
#     cgpa  resume_score  placed
# 0     12             8       1
# 1     10             7       0
# 2     12            10       1
# 3     10             9       1
# 4     11             9       1
# ..   ...           ...     ...
# 95    10             8       0
# 96    12             9       1
# 97    10             9       0
# 98    12             7       1
# 99    10             8       0
#
# [100 rows x 3 columns]
